# %% [markdown]
# <a href="https://colab.research.google.com/github/deiivid10/deiivid10/blob/main/EJEMPLO1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir el rango de valores para x
x = np.linspace(-10, 10, 400)

# Definir la ecuación de la parábola
y = x**2

# Crear la gráfica
plt.plot(x, y, label=r'$y = x^2$')

# Etiquetas de los ejes
plt.xlabel('x')
plt.ylabel('y')

# Título de la gráfica
plt.title('Gráfica de una parábola')

# Mostrar la
# Out:
# Text(0.5, 1.0, 'Gráfica de una parábola')
